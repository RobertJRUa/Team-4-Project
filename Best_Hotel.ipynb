# %%
# Import dependencies 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json 
import requests
import time
from citipy import citipy

# Import api key 
from api_keys import gkey

# %%
# Build base url for text search 
text_type = "lodging"
location = "hotels in Cuyahoga County"

text_url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"

params = {"type" : text_type,
         "query" : location,
         "key" : gkey}

response = requests.get(text_url, params=params)
cuyahoga_text = response.json()

print(json.dumps(cuyahoga_text, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CqQCEQEAAL6AEF0rdIycOyeOzU55HYRlglS7-yJi2rCMq2d55UdO-PMrPixxHREIEiTuBnvelOHzREHhtr6O-pGyig8a6Y3oq6uUwYwNytmud0yLmWuY8zmuUB9sS3bXgLtz1bP5pdktLmg5NRAC5NkbbYMkBXfRup9hBRZt0dJvY4MClHqbhJvXhhm7bnEZ_E10yfRA72IMNHDsgSwbZCDYmtmp8QDUfsX-m7wpP48y56CV_czxwNsWCbKJZRu5brjzgZdU_B_6_6_unEms6YAKg12_LF3Q9dyF7Ol1e9U6WKVMFpL3aS56dbea-odsS14esZJng4UQm17RjZ4EozuQyQ8RYvNPq4rxNeCCVat2jnK4OPgEmXYmjYO5uLmns1Lk-xrkMBIQOMp5XoZm455TfdsRngpJRhoUt8Aykk43ViHXsAwmoAUpQtxbYDA",
#     "results": [
#         {
#             "formatted_address": "15471 Royalton Rd, Strongsville, OH 44136, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.3116804,
#                     "lng": -81.80746049999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.31315207989272,
#                         "lng": -81.80586907010728
#                     },
# ...

# %%
# Show response url 
response.url
# Out:
# 'https://maps.googleapis.com/maps/api/place/textsearch/json?type=lodging&query=hotels+in+Cuyahoga+County&key=AIzaSyA1yTwp7ia1h-TvWcYRc1mUAN1o4Pq713g'

# %%
# Create lists to hold all of our data points
#address = []
lat = []
lng = []
name = []
place_id = []
rating = []
user_ratings_total = []
types = []

# %%
# Building lists 
address = cuyahoga_text["formatted_address"]


#lat.append(response[])
#lng.append(response[])
#name.append(response[])
#place_id.append(response[])
#rating.append(response[])
#user_ratings_total.append(response[])
#types.append(response[])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-e2616c7c6bdf> in <module>
#       1 # Building lists
# ----> 2 address = cuyahoga_text["formatted_address"]
#       3
#       4
#       5 #lat.append(response[])
#
# KeyError: 'formatted_address'

# %%
# It's time to traverse through json
