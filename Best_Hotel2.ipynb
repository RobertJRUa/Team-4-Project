# %%
# Import dependencies 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json 
import requests
import time
from citipy import citipy

# Import api key 
from api_keys import gkey

# %%
# Build base url for text search 
nearby_type = "lodging"
target_coordinates = '41.5048, -81.6857'
radius = 8046.72
target_search = 'hotel'

nearby_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"

params = {"type" : nearby_type,
          'keyword' : target_search,
         "location" : target_coordinates,
          'radius': radius,
         "key" : gkey}

response = requests.get(nearby_url, params=params)
cleveland_nearby = response.json()

print(json.dumps(cleveland_nearby, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CrQCJQEAANZY1LsHOy40cL74o-JOluVh5a2VNblPNbtZalZwa2U1z2tYcx2cLLCwZ4VNZZgYZv1FUwpUvSAwJfCmvpAhox866aUIi7RqOKMH1iTvxzdWIYzU7h4O0WMRorUrtnAvQP6KgyrYxgaTueShZRglnlLVAB8lW3ygAyaGyQ6FIiMjdblI23BuCxF_IhWWz3Xr5lp46tU_P-MUhPY9E17qTaX9YWjqKgdurYmNinXTh0FAq2E6X3DjFY0LyLhj9tqx_VRdPLVUO6fWzlfx_R-9F7e_wKHOrQ2cQIDn7tacKvHJmROZKOBIw86T6mvX6XStRm9eVZVBzU91sCcmtB2Fqcx1zBmkMpuYxoMK-GVwUI6sMKowpNZi51BcHRvtTakq1brGy0nYP2dqnwWWf41EU7gSEINH1vNX-ZI5vEtWfHp1QY8aFLVm8ADrt2SKy4fzbklzxUSU2nvM",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.4986106,
#                     "lng": -81.6944717
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50012227989272,
#                         "lng": -81.69334847010727
#                     },
#                     "southwest": {
#                         "lat": 41.49742262010728,
#                         "lng": -81.69604812989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "dc96131c3dfcbcb2ac7e13ed64d123ee87082ee6",
#             "name": "Renaissance Cleveland Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 423,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106505317315732722159/photos\">Renaissance Cleveland Hotel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAhEGx2Wn-_Ug9C78Symxrpo0DTdNoRHYpKtbp_ZJVsJITK33TuxyS6VY8TRf4t5HBM21qZERYWAS_PJ3tE_ZhQ4A8v5pGREVVntq9LJqXqgRBMwenWlD2e8Q5sZidSNi-EhDVL2rioca8qBMGBHDfENpuGhSivFNPQlZF-FmCv8BV5nD3ZI36SQ",
#                     "width": 610
#                 }
#             ],
#             "place_id": "ChIJQdJiRX7wMIgRMHYixWs56JQ",
#             "plus_code": {
#                 "compound_code": "F8X4+C6 Cleveland, Ohio, USA",
#                 "global_code": "86HWF8X4+C6"
#             },
#             "rating": 4.1,
#             "reference": "ChIJQdJiRX7wMIgRMHYixWs56JQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1088,
#             "vicinity": "24 Public Square, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5005708,
#                     "lng": -81.7041148
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50187337989272,
#                         "lng": -81.70285247010727
#                     },
#                     "southwest": {
#                         "lat": 41.49917372010728,
#                         "lng": -81.70555212989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "2a074fb880ae8a4483f52aa2f53f4835c83e5bcd",
#             "name": "Aloft Cleveland Downtown",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106926295935055455922/photos\">Aloft Cleveland Downtown</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAqz_pbspkahgxC-20-sIqKqinX0C9xkrctkfzZoE_BObXmXlA7a3ippwEjEvTqVwwHN_Szufe4df61Ft9AOyqApGGTJiTp7qJXa6mSQ6oPpiV2jax1w7eGFHLYDTQcCmPEhB7OAfMATulHg8wHSygV07JGhQCYZFbbvIpxBhSxdrcGkWpZcSp_Q",
#                     "width": 1500
#                 }
#             ],
#             "place_id": "ChIJ-V-1mmLwMIgRCNkQ5iY0w6w",
#             "plus_code": {
#                 "compound_code": "G72W+69 Cleveland, Ohio, USA",
#                 "global_code": "86HWG72W+69"
#             },
#             "rating": 4.2,
#             "reference": "ChIJ-V-1mmLwMIgRCNkQ5iY0w6w",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1055,
#             "vicinity": "1111 W 10th St, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.50701,
#                     "lng": -81.6901721
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50844367989272,
#                         "lng": -81.68864007010728
#                     },
#                     "southwest": {
#                         "lat": 41.50574402010728,
#                         "lng": -81.69133972989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "

#                     "width": 3840
#                 }
#             ],
#             "place_id": "ChIJm_rT55v7MIgRkVJ4n5CNiOE",
#             "plus_code": {
#                 "compound_code": "G92J+H7 Cleveland, Ohio, USA",
#                 "global_code": "86HWG92J+H7"
#             },
#             "rating": 4.5,
#             "reference": "ChIJm_rT55v7MIgRkVJ4n5CNiOE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 685,
#             "vicinity": "9801 Carnegie Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5030649,
#                     "lng": -81.6252999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50435477989272,
#                         "lng": -81.62381397010726
#                     },
#                     "southwest": {
#                         "lat": 41.50165512010728,
#                         "lng": -81.62651362989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "16c4160012583af17b2d8b58cf86791f89c666a9",
#             "name": "InterContinental Suites Hotel Cleveland",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1836,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103453579842648476437/photos\">Sandeep Kulkarni</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAw764zpz_Rauz00vgJ6yaX-yqvO97l14772OfwHZKyS51VvazQgYb6y11uewCIeYyP_H2WdXRXRoBX9gZnKzLMbcusINr3Vae-SU571noL7chgR_e_31xQ-adkcYFEDnPEhBIsppp_QeCtPhW8OHzbzqEGhRUiNuIF37lIJA45KgttDeiWfCcKw",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJs9bne5j7MIgRK7gn3Ut37mE",
#             "plus_code": {
#                 "compound_code": "G93F+6V Cleveland, Ohio, USA",
#                 "global_code": "86HWG93F+6V"
#             },
#             "rating": 4.3,
#             "reference": "ChIJs9bne5j7MIgRK7gn3Ut37mE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 423,
#             "vicinity": "8800 Euclid Ave, Cleveland"
#         }
#     ],
#     "status": "OK"
# }

# %%
# Show response url 
response.url
# Out:
# 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?type=lodging&keyword=hotel&location=41.5048%2C+-81.6857&radius=8046.72&key=AIzaSyA1yTwp7ia1h-TvWcYRc1mUAN1o4Pq713g'

# %%
# Create lists to hold all of our data points
address = []
lat = []
lng = []
name = []
place_id = []
rating = []
user_ratings_total = []
types = []

# %%
# Building lists 
for element in cleveland_nearby['results']:
    #address.append(element['formatted_address'])
    lat.append(element['geometry']['location']['lat'])
    lng.append(element['geometry']['location']['lng'])
    name.append(element['name'])
    place_id.append(element['place_id'])
    rating.append(element['rating'])
    user_ratings_total.append(element['user_ratings_total'])
    types.append(element['types'])

# %%
# We are going to merge DataFrames on place_id, so let's get the len of place_id
len(place_id)
# Out:
# 20

# %%
print(name)
# Out:
# ['Renaissance Cleveland Hotel', 'Aloft Cleveland Downtown', 'DoubleTree by Hilton Hotel Cleveland Downtown - Lakeside', 'Hilton Cleveland Downtown', 'Hyatt Regency Cleveland At The Arcade', 'The Tudor Arms Hotel Cleveland - a DoubleTree by Hilton', 'Holiday Inn Express Cleveland Downtown', 'Drury Plaza Hotel Cleveland Downtown', 'Metropolitan at the 9, Autograph Collection', 'Hilton Garden Inn Cleveland Downtown', 'The Westin Cleveland Downtown', 'Hampton Inn Cleveland-Downtown', 'Residence Inn by Marriott Cleveland Downtown', 'Courtyard by Marriott Cleveland University Circle', 'Radisson Hotel Cleveland-Gateway', 'Holiday Inn Cleveland Clinic', 'Kimpton Schofield Hotel', 'Cleveland Marriott Downtown at Key Tower', 'InterContinental Cleveland', 'InterContinental Suites Hotel Cleveland']

# %%
print(place_id)
# Out:
# ['ChIJQdJiRX7wMIgRMHYixWs56JQ', 'ChIJ-V-1mmLwMIgRCNkQ5iY0w6w', 'ChIJkyQK63j6MIgR3WshTHAP94Q', 'ChIJ9WAy2YDwMIgRqgktebGbYoM', 'ChIJU79i-X_6MIgRgAo4Y1a36zw', 'ChIJM5WTlIT7MIgRZXbXABw3OQw', 'ChIJ8b9IeID6MIgRg7cfACiPh8I', 'ChIJz9VrMIDwMIgRU4dHrxBVI1k', 'ChIJE6DsqoD6MIgRheks77AlZ9w', 'ChIJtxcBOYb6MIgRW5MU3e2Lqew', 'ChIJjQ5B2YHwMIgRjNnpAsJKuBg', 'ChIJewgGqX_6MIgRVI5s1kAUzyk', 'ChIJY8UhA2L6MIgRjU4eiYtqbnM', 'ChIJ0bg0mIn7MIgRdLO0rIQ4ndc', 'ChIJA-0v8ID6MIgRBACI0VNvqr8', 'ChIJx3A1jKL7MIgRQwfzeK-X6Mc', 'ChIJowjHoID6MIgRYkqUBQC5bmk', 'ChIJlzqOKX7wMIgRcG1mp3KKt8s', 'ChIJm_rT55v7MIgRkVJ4n5CNiOE', 'ChIJs9bne5j7MIgRK7gn3Ut37mE']

# %%
# Create first DataFrame for hotel data 
place_df = pd.DataFrame({'Name': name, 'Place_ID': place_id, 'Latitude': lat,
                         'Longitude': lng, 'Rating': rating, 'Total Reviews': user_ratings_total,
                         'Types': types})
place_df
# Out:
#                                                  Name  \
# 0                         Renaissance Cleveland Hotel
# 1                            Aloft Cleveland Downtown
# 2   DoubleTree by Hilton Hotel Cleveland Downtown ...
# 3                           Hilton Cleveland Downtown
# 4               Hyatt Regency Cleveland At The Arcade
# 5   The Tudor Arms Hotel Cleveland - a DoubleTree ...
# 6              Holiday Inn Express Cleveland Downtown
# 7                Drury Plaza Hotel Cleveland Downtown
# 8         Metropolitan at the 9, Autograph Collection
# 9                Hilton Garden Inn Cleveland Downtown
# 10                      The Westin Cleveland Downtown
# 11                     Hampton Inn Cleveland-Downtown
# 12       Residence Inn by Marriott Cleveland Downtown
# 13  Courtyard by Marriott Cleveland University Circle
# 14                   Radisson Hotel Cleveland-Gateway
# 15                       Holiday Inn Cleveland Clinic
# 16                            Kimpton Schofield Hotel
# 17           Cleveland Marriott Downtown at Key Tower
# 18                         InterContinental Cleveland
# 19            InterContinental Suites Hotel Cleveland
#
#                        Place_ID   Latitude  Longitude  Rating  Total Reviews  \
# 0   ChIJQdJiRX7wMIgRMHYixWs56JQ  41.498611 -81.694472     4.1           1088
# 1   ChIJ-V-1mmLwMIgRCNkQ5iY0w6w  41.500571 -81.704115     4.2           1055
# 2   ChIJkyQK63j6MIgR3WshTHAP94Q  41.507010 -81.690172     4.1           1503
# 3   ChIJ9WAy2YDwMIgRqgktebGbYoM  41.503072 -81.695672     4.5           2141
# 4   ChIJU79i-X_6MIgRgAo4Y1a36zw  41.499789 -81.690841     4.4           1296
# 5   ChIJM5WTlIT7MIgRZXbXABw3OQw  41.500816 -81.612958     4.3            866
# 6   ChIJ8b9IeID6MIgRg7cfACiPh8I  41.500186 -81.688767     4.3            904
# 7   ChIJz9VrMIDwMIgRU4dHrxBVI1k  41.502174 -81.691969     4.6           1050
# 8   ChIJE6DsqoD6MIgRheks77AlZ9w  41.499788 -81.685809     4.5            975
# 9   ChIJtxcBOYb6MIgRW5MU3e2Lqew  41.496152 -81.681146     4.1           1083
# 10  ChIJjQ5B2YHwMIgRjNnpAsJKuBg  41.503725 -81.691413     4.4           1719
# 11  ChIJewgGqX_6MIgRVI5s1kAUzyk  41.502438 -81.689041     4.2            884
# 12  ChIJY8UhA2L6MIgRjU4eiYtqbnM  41.498710 -81.689022     4.4            465
# 13  ChIJ0bg0mIn7MIgRdLO0rIQ4ndc  41.507961 -81.605262     4.3            449
# 14  ChIJA-0v8ID6MIgRBACI0VNvqr8  41.498140 -81.687691     3.9            784
# 15  ChIJx3A1jKL7MIgRQwfzeK-X6Mc  41.503027 -81.626370     4.2            787
# 16  ChIJowjHoID6MIgRYkqUBQC5bmk  41.499811 -81.686762     4.5            532
# 17  ChIJlzqOKX7wMIgRcG1mp3KKt8s  41.501619 -81.693939     4.3           1373
# 18  ChIJm_rT55v7MIgRkVJ4n5CNiOE  41.501449 -81.619343     4.5            685
# 19  ChIJs9bne5j7MIgRK7gn3Ut37mE  41.503065 -81.625300     4.3            423
#
#                                           Types
# 0   [lodging, point_of_interest, establishment]
# 1   [lodging, point_of_interest, establishment]
# 2   [lodging, point_of_interest, establishment]
# 3   [lodging, point_of_interest, establishment]
# 4   [lodging, point_of_interest, establishment]
# 5   [lodging, point_of_interest, establishment]
# 6   [lodging, point_of_interest, establishment]
# 7   [lodging, point_of_interest, establishment]
# 8   [lodging, point_of_interest, establishment]
# 9   [lodging, point_of_interest, establishment]
# 10  [lodging, point_of_interest, establishment]
# 11  [lodging, point_of_interest, establishment]
# 12  [lodging, point_of_interest, establishment]
# 13  [lodging, point_of_interest, establishment]
# 14  [lodging, point_of_interest, establishment]
# 15  [lodging, point_of_interest, establishment]
# 16  [lodging, point_of_interest, establishment]
# 17  [lodging, point_of_interest, establishment]
# 18  [lodging, point_of_interest, establishment]
# 19  [lodging, point_of_interest, establishment]

# %%
# Build base url for text search 
nearby_type = "lodging"
target_coordinates = '41.5048, -81.6857'
radius = 1609
target_search = 'hotel'

nearby_url2 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?pagetoken=
"ChIJc3VeZFn6MIgRDfZmd6I8NQo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 590,
#             "vicinity": "3614 Euclid Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5030718,
#                     "lng": -81.6956723
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50454197989273,
#                         "lng": -81.69443002010728
#                     },
#                     "southwest": {
#                         "lat": 41.50184232010729,
#                         "lng": -81.69712967989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "e1cecb9fa307093a77c1f4ead901174768a84ce8",
#             "name": "Hilton",
#             "place_id": "ChIJn72y7Xj6MIgRRjyFgT8IMZk",
#             "plus_code": {
#                 "compound_code": "G833+6P Cleveland, Ohio, USA",
#                 "global_code": "86HWG833+6P"
#             },
#             "rating": 4.8,
#             "reference": "ChIJn72y7Xj6MIgRRjyFgT8IMZk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4,
#             "vicinity": "100 Lakeside Ave E, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.50066,
#                     "lng": -81.68475839999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50197592989272,
#                         "lng": -81.68339997010729
#                     },
#                     "southwest": {
#                         "lat": 41.49927627010728,
#                         "lng": -81.68609962989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "4dc95366bb2c00b16be49d82acb7810baab6a67b",
#             "name": "Park Today",
#             "place_id": "ChIJp1rJ7n36MIgRwwpkpwISUWw",
#             "plus_code": {
#                 "compound_code": "G828+73 Cleveland, Ohio, USA",
#                 "global_code": "86HWG828+73"
#             },
#             "rating": 0,
#             "reference": "ChIJp1rJ7n36MIgRwwpkpwISUWw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "1127 Euclid Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5030197,
#                     "lng": -81.66613
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50422802989272,
#                         "lng": -81.66475757010727
#                     },
#                     "southwest": {
#                         "lat": 41.50152837010728,
#                         "lng": -81.6674572298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d3fbea6fb80cc8d2a08def4e7860c85ee318cc49",
#             "name": "catawba yacht club",
#             "place_id": "ChIJF2AFhF76MIgRil1XbzWM2ZM",
#             "plus_code": {
#                 "compound_code": "G83M+6G Cleveland, Ohio, USA",
#                 "global_code": "86HWG83M+6G"
#             },
#             "rating": 0,
#             "reference": "ChIJF2AFhF76MIgRil1XbzWM2ZM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "3121 Euclid Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5085071,
#                     "lng": -81.67446369999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.51004162989272,
#                         "lng": -81.67324402010728
#                     },
#                     "southwest": {
#                         "lat": 41.50734197010728,
#                         "lng": -81.67594367989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "c3fc2f51b41a420cb26f846150c02e20b9388742",
#             "name": "redspot",
#             "place_id": "ChIJDXyNBmb6MIgRvw-P0NGHHXo",
#             "plus_code": {
#                 "compound_code": "G85G+C6 Cleveland, Ohio, USA",
#                 "global_code": "86HWG85G+C6"
#             },
#             "rating": 0,
#             "reference": "ChIJDXyNBmb6MIgRvw-P0NGHHXo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "2400 Superior Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5008836,
#                     "lng": -81.6784514
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50241417989272,
#                         "lng": -81.67705212010729
#                     },
#                     "southwest": {
#                         "lat": 41.49971452010728,
#                         "lng": -81.67975177989274
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "65f17f8a9863f74a0cca45c288af9db92b437872",
#             "name": "1800 Euclid Hospitality Group",
#             "place_id": "ChIJI23g52L6MIgR71RRKXfUJuw",
#             "plus_code": {
#                 "compound_code": "G82C+9J Cleveland, Ohio, USA",
#                 "global_code": "86HWG82C+9J"
#             },
#             "rating": 4.7,
#             "reference": "ChIJI23g52L6MIgR71RRKXfUJuw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "1800 Euclid Ave # 1, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5004615,
#                     "lng": -81.6833738
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50190117989273,
#                         "lng": -81.68204442010727
#                     },
#                     "southwest": {
#                         "lat": 41.49920152010728,
#                         "lng": -81.68474407989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "287b03d00231da73bac1cad7a805e09a2d0e795d",
#             "name": "Crowne Plaza Cleveland at Playhouse Square",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110636021344697030653/photos\">Brian Johnson</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAJpnVUsuK5LeBPpmwNjrA4YaYAyF4kmp_zIPgqXJMu6m5KTYt-xafTjAM3bF45uhtc52EtedbRQeYnwCehRC19Ljg2xjx2YCSxxg8gM-AWG9QUgjX9q4XdKy9gMj-WKxHEhCB2sQDkiLwb6m-LnNracqBGhRK6N-8tceRM0Mk7h3sLn_ZF3pcmw",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJp252m336MIgRX9QDJIGuKFU",
#             "plus_code": {
#                 "compound_code": "G828+5M Cleveland, Ohio, USA",
#                 "global_code": "86HWG828+5M"
#             },
#             "rating": 4.2,
#             "reference": "ChIJp252m336MIgRX9QDJIGuKFU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 505,
#             "vicinity": "1260 Euclid Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.4687294,
#                     "lng": -81.6873671
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.47007877989272,
#                         "lng": -81.68614082010728
#                     },
#                     "southwest": {
#                         "lat": 41.46737912010727,
#                         "lng": -81.68884047989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d2ec5a7f626349927d7de4538026cd802bc74678",
#             "name": "A Christmas Story House Loft Rental",
#             "photos": [
#                 {
#                     "height": 3036,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117382712380336441981/photos\">Rex Mercer</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAcoSYYC1KY6J5Jm7_Oe8CXHqoCDkb4WMyScEed4EhNs7e12dERMjdo02m7ahDZv5S1nOx-lJdV7jGTBqEXDV-REOwsPgZ-vzOWa4EWRHcGC5ejBU8kiV5sfGwO60K96a8EhBIugMHyQIUjbcsqfcTpLU3GhTy8ljHjVX-p2BeVcu25uJ9n7IzTA",
#                     "width": 4048
#                 }
#             ],
#             "place_id": "ChIJVeZ366j6MIgRIVvD0qSYsh4",
#             "plus_code": {
#                 "compound_code": "F897+F3 Cleveland, Ohio, USA",
#                 "global_code": "86HWF897+F3"
#             },
#             "rating": 5,
#             "reference": "ChIJVeZ366j6MIgRIVvD0qSYsh4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "3159 W 11th St, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.4923165,
#                     "lng": -81.5975297
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.49353402989272,
#                         "lng": -81.59642642010728
#                     },
#                     "southwest": {
#                         "lat": 41.49083437010728,
#                         "lng": -81.59912607989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "5a6797fc18e4d56070e19bcaaf9638e979574513",
#             "name": "hotels",
#             "place_id": "ChIJ3e-GwKj9MIgRXRcfIWWv1to",
#             "plus_code": {
#                 "compound_code": "FCR2+WX Cleveland, Ohio, USA",
#                 "global_code": "86HWFCR2+WX"
#             },
#             "rating": 0,
#             "reference": "ChIJ3e-GwKj9MIgRXRcfIWWv1to",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "12200 Fairhill Rd # B414, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.509068,
#                     "lng": -81.6731133
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.51061907989272,
#                         "lng": -81.67204497010727
#                     },
#                     "southwest": {
#                         "lat": 41.50791942010728,
#                         "lng": -81.67474462989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "34d363d6f48eac4ef2504f6f9fa62c1a199624fc",
#             "name": "Urban Design Suite",
#             "place_id": "ChIJa7UAmWj6MIgRySQrPk4BO_E",
#             "plus_code": {
#                 "compound_code": "G85G+JQ Cleveland, Ohio, USA",
#                 "global_code": "86HWG85G+JQ"
#             },
#             "rating": 0,
#             "reference": "ChIJa7UAmWj6MIgRySQrPk4BO_E",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "2570 Superior Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5016031,
#                     "lng": -81.619175
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50287387989273,
#                         "lng": -81.61793067010727
#                     },
#                     "southwest": {
#                         "lat": 41.50017422010728,
#                         "lng": -81.62063032989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "495688a1178c154f4e798c8d8cbc5bceda0c0c16",
#             "name": "The Alcazar",
#             "place_id": "ChIJ1TzoxJv7MIgRWiijLUrBJrE",
#             "plus_code": {
#                 "compound_code": "G92J+J8 Cleveland, Ohio, USA",
#                 "global_code": "86HWG92J+J8"
#             },
#             "rating": 0,
#             "reference": "ChIJ1TzoxJv7MIgRWiijLUrBJrE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "9801 Carnegie Ave, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.4971659,
#                     "lng": -81.6940644
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.49857627989272,
#                         "lng": -81.69271077010728
#                     },
#                     "southwest": {
#                         "lat": 41.49587662010728,
#                         "lng": -81.69541042989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "356c6a5e45bda77eb0d2d30c8c6156da18d62864",
#             "name": "Casino Hotel",
#             "place_id": "ChIJm1xx_rrxMIgRmUQR0Wpz_7o",
#             "plus_code": {
#                 "compound_code": "F8W4+V9 Cleveland, Ohio, USA",
#                 "global_code": "86HWF8W4+V9"
#             },
#             "rating": 0,
#             "reference": "ChIJm1xx_rrxMIgRmUQR0Wpz_7o",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "250 W Huron Rd, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.49932,
#                     "lng": -81.6943605
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50066982989272,
#                         "lng": -81.69301067010727
#                     },
#                     "southwest": {
#                         "lat": 41.49797017010727,
#                         "lng": -81.69571032989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "74880db63a8dbb78bb19df19726053527f2e2237",
#             "name": "USA",
#             "place_id": "ChIJq3GuHHjxMIgRVi6vJMesADI",
#             "plus_code": {
#                 "compound_code": "F8X4+P7 Cleveland, Ohio, USA",
#                 "global_code": "86HWF8X4+P7"
#             },
#             "rating": 0,
#             "reference": "ChIJq3GuHHjxMIgRVi6vJMesADI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.4690375,
#                     "lng": -81.6873737
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.47032122989273,
#                         "lng": -81.68617222010727
#                     },
#                     "southwest": {
#                         "lat": 41.46762157010728,
#                         "lng": -81.68887187989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "8edd3b78cdb0b2af5cdbf20ac36ec99e460010e2",
#             "name": "The Bumpus House",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107989028313692403462/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAujWwxD8v28918UzTr5xXF403nuGoolI8gsLW6fmjx2z-sEMzaAOkiPARlJ76aDc_bvtufJ3v5P-_smefCblLmSOi07_2EQfkc61GxEolMAjZPKA8BOxX8pWH3_tTbW5bEhCfRvOB_9PZVCculV5cuAaEGhQV5ND-CWI3CZJ3SkyId_8V9pWF7A",
#                     "width": 1357
#                 }
#             ],
#             "place_id": "ChIJIRHsk9j7MIgRaAv5LgVWd7Y",
#             "plus_code": {
#                 "compound_code": "F897+J3 Cleveland, Ohio, USA",
#                 "global_code": "86HWF897+J3"
#             },
#             "rating": 4.2,
#             "reference": "ChIJIRHsk9j7MIgRaAv5LgVWd7Y",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5,
#             "vicinity": "3153 W 11th St, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.49813959999999,
#                     "lng": -81.6876913
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.49948942989272,
#                         "lng": -81.68634147010727
#                     },
#                     "southwest": {
#                         "lat": 41.49678977010728,
#                         "lng": -81.68904112989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "f1af5c6d8c1effb6e85e8b3032ec294134bef685",
#             "name": "Hotel Cleveland Gateway",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJ6xhOyTP7MIgRG5i0LXBcqn8",
#             "plus_code": {
#                 "compound_code": "F8X6+7W Cleveland, Ohio, USA",
#                 "global_code": "86HWF8X6+7W"
#             },
#             "rating": 0,
#             "reference": "ChIJ6xhOyTP7MIgRG5i0LXBcqn8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "651 Huron Rd E, Cleveland"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.4901543,
#                     "lng": -81.7708111
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.49164112989272,
#                         "lng": -81.76939537010729
#                     },
#                     "southwest": {
#                         "lat": 41.48894147010727,
#                         "lng": -81.77209502989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "113208734bc8302be77c0d76ee7b3b90a7968c89",
#             "name": "Travelodge by Wyndham Cleveland Lakewood",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1440,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105253649670751782980/photos\">*Duke*</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAoxQcSQCjdNoXeRSAReHzIXBY9Y9b2_OSYJekCgkv8SdJHXpzQJQqG6cRWtJzx_g_vrfFzHtG970xS47JHL0SWxQLEcw5pmDk-vI8jgyzYG8oPZY0wQbWIVk1z9iGGkQTEhAacYqN6OdcyP5gopL_xbZwGhTRWskM4dYnhbBn0z7-YScSOSsPEQ",
#                     "width": 2560
#                 }
#             ],
#             "place_id": "ChIJ_fHRM4zxMIgRepudzosPQG0",
#             "plus_code": {
#                 "compound_code": "F6RH+3M Lakewood, Ohio, USA",
#                 "global_code": "86HWF6RH+3M"
#             },
#             "rating": 3.5,
#             "reference": "ChIJ_fHRM4zxMIgRepudzosPQG0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 266,
#             "vicinity": "11837 Edgewater Dr, Lakewood"
#         }
#     ],
#     "status": "OK"
# }

# %%
# Building the second DataFrame
#lat2 = []
#lng2 = []
#name2 = []
#place_id2 = []
#rating2 = []
#user_ratings_total2 = []
#types2 = []

# Building lists 
for element in cleveland_nearby2['results']:
    lat.append(element['geometry']['location']['lat'])
    lng.append(element['geometry']['location']['lng'])
    name.append(element['name'])
    place_id.append(element['place_id'])
    rating.append(element['rating'])
    user_ratings_total.append(element['user_ratings_total'])
    types.append(element['types'])
	
place_df = pd.DataFrame({'Name': name, 'Latitude': lat, 'Place_ID': place_id, 
                          'Longitude': lng, 'Rating': rating, 'Total Reviews': user_ratings_total, 
                          'Types': types})
place_df
# Out:
#                                                  Name   Latitude  \
# 0                         Renaissance Cleveland Hotel  41.498611
# 1                            Aloft Cleveland Downtown  41.500571
# 2   DoubleTree by Hilton Hotel Cleveland Downtown ...  41.507010
# 3                           Hilton Cleveland Downtown  41.503072
# 4               Hyatt Regency Cleveland At The Arcade  41.499789
# 5   The Tudor Arms Hotel Cleveland - a DoubleTree ...  41.500816
# 6              Holiday Inn Express Cleveland Downtown  41.500186
# 7                Drury Plaza Hotel Cleveland Downtown  41.502174
# 8         Metropolitan at the 9, Autograph Collection  41.499788
# 9                Hilton Garden Inn Cleveland Downtown  41.496152
# 10                      The Westin Cleveland Downtown  41.503725
# 11                     Hampton Inn Cleveland-Downtown  41.502438
# 12       Residence Inn by Marriott Cleveland Downtown  41.498710
# 13  Courtyard by Marriott Cleveland University Circle  41.507961
# 14                   Radisson Hotel Cleveland-Gateway  41.498140
# 15                       Holiday Inn Cleveland Clinic  41.503027
# 16                            Kimpton Schofield Hotel  41.499811
# 17           Cleveland Marriott Downtown at Key Tower  41.501619
# 18                         InterContinental Cleveland  41.501449
# 19            InterContinental Suites Hotel Cleveland  41.503065
# 20              Hyatt Regency Cleveland At The Arcade  41.499789
# 21                       Holiday Inn Cleveland Clinic  41.503027
# 22            InterContinental Suites Hotel Cleveland  41.503065
# 23                                      Glidden House  41.510944
# 24                        University Hotel and Suites  41.502686
# 25                                             Hilton  41.503072
# 26                                         Park Today  41.500660
# 27                                 catawba yacht club  41.503020
# 28                                            redspot  41.508507
# 29                      1800 Euclid Hospitality Group  41.500884
# 30         Crowne Plaza Cleveland at Playhouse Square  41.500462
# 31                A Christmas Story House Loft Rental  41.468729
# 32                                             hotels  41.492317
# 33                                 Urban Design Suite  41.509068
# 34                                        The Alcazar  41.501603
# 35                                       Casino Hotel  41.497166
# 36                                                USA  41.499320
# 37                                   The Bumpus House  41.469037
# 38                            Hotel Cleveland Gateway  41.498140
# 39           Travelodge by Wyndham Cleveland Lakewood  41.490154
#
#                        Place_ID  Longitude  Rating  Total Reviews  \
# 0   ChIJQdJiRX7wMIgRMHYixWs56JQ -81.694472     4.1           1088
# 1   ChIJ-V-1mmLwMIgRCNkQ5iY0w6w -81.704115     4.2           1055
# 2   ChIJkyQK63j6MIgR3WshTHAP94Q -81.690172     4.1           1503
# 3   ChIJ9WAy2YDwMIgRqgktebGbYoM -81.695672     4.5           2141
# 4   ChIJU79i-X_6MIgRgAo4Y1a36zw -81.690841     4.4           1296
# 5   ChIJM5WTlIT7MIgRZXbXABw3OQw -81.612958     4.3            866
# 6   ChIJ8b9IeID6MIgRg7cfACiPh8I -81.688767     4.3            904
# 7   ChIJz9VrMIDwMIgRU4dHrxBVI1k -81.691969     4.6           1050
# 8   ChIJE6DsqoD6MIgRheks77AlZ9w -81.685809     4.5            975
# 9   ChIJtxcBOYb6MIgRW5MU3e2Lqew -81.681146     4.1           1083
# 10  ChIJjQ5B2YHwMIgRjNnpAsJKuBg -81.691413     4.4           1719
# 11  ChIJewgGqX_6MIgRVI5s1kAUzyk -81.689041     4.2            884
# 12  ChIJY8UhA2L6MIgRjU4eiYtqbnM -81.689022     4.4            465
# 13  ChIJ0bg0mIn7MIgRdLO0rIQ4ndc -81.605262     4.3            449
# 14  ChIJA-0v8ID6MIgRBACI0VNvqr8 -81.687691     3.9            784
# 15  ChIJx3A1jKL7MIgRQwfzeK-X6Mc -81.626370     4.2            787
# 16  ChIJowjHoID6MIgRYkqUBQC5bmk -81.686762     4.5            532
# 17  ChIJlzqOKX7wMIgRcG1mp3KKt8s -81.693939     4.3           1373
# 18  ChIJm_rT55v7MIgRkVJ4n5CNiOE -81.619343     4.5            685
# 19  ChIJs9bne5j7MIgRK7gn3Ut37mE -81.625300     4.3            423
# 20  ChIJU79i-X_6MIgRgAo4Y1a36zw -81.690841     4.4           1296
# 21  ChIJx3A1jKL7MIgRQwfzeK-X6Mc -81.626370     4.2            787
# 22  ChIJs9bne5j7MIgRK7gn3Ut37mE -81.625300     4.3            423
# 23  ChIJv1Qamov7MIgRAUiBRQkU2-A -81.607877     4.7            337
# 24  ChIJc3VeZFn6MIgRDfZmd6I8NQo -81.661900     2.8            590
# 25  ChIJn72y7Xj6MIgRRjyFgT8IMZk -81.695672     4.8              4
# 26  ChIJp1rJ7n36MIgRwwpkpwISUWw -81.684758     0.0              0
# 27  ChIJF2AFhF76MIgRil1XbzWM2ZM -81.666130     0.0              0
# 28  ChIJDXyNBmb6MIgRvw-P0NGHHXo -81.674464     0.0              0
# 29  ChIJI23g52L6MIgR71RRKXfUJuw -81.678451     4.7              3
# 30  ChIJp252m336MIgRX9QDJIGuKFU -81.683374     4.2            505
# 31  ChIJVeZ366j6MIgRIVvD0qSYsh4 -81.687367     5.0              3
# 32  ChIJ3e-GwKj9MIgRXRcfIWWv1to -81.597530     0.0              0
# 33  ChIJa7UAmWj6MIgRySQrPk4BO_E -81.673113     0.0              0
# 34  ChIJ1TzoxJv7MIgRWiijLUrBJrE -81.619175     0.0              0
# 35  ChIJm1xx_rrxMIgRmUQR0Wpz_7o -81.694064     0.0              0
# 36  ChIJq3GuHHjxMIgRVi6vJMesADI -81.694361     0.0              0
# 37  ChIJIRHsk9j7MIgRaAv5LgVWd7Y -81.687374     4.2              5
# 38  ChIJ6xhOyTP7MIgRG5i0LXBcqn8 -81.687691     0.0              0
# 39  ChIJ_fHRM4zxMIgRepudzosPQG0 -81.770811     3.5            266
#
#                                           Types
# 0   [lodging, point_of_interest, establishment]
# 1   [lodging, point_of_interest, establishment]
# 2   [lodging, point_of_interest, establishment]
# 3   [lodging, point_of_interest, establishment]
# 4   [lodging, point_of_interest, establishment]
# 5   [lodging, point_of_interest, establishment]
# 6   [lodging, point_of_interest, establishment]
# 7   [lodging, point_of_interest, establishment]
# 8   [lodging, point_of_interest, establishment]
# 9   [lodging, point_of_interest, establishment]
# 10  [lodging, point_of_interest, establishment]
# 11  [lodging, point_of_interest, establishment]
# 12  [lodging, point_of_interest, establishment]
# 13  [lodging, point_of_interest, establishment]
# 14  [lodging, point_of_interest, establishment]
# 15  [lodging, point_of_interest, establishment]
# 16  [lodging, point_of_interest, establishment]
# 17  [lodging, point_of_interest, establishment]
# 18  [lodging, point_of_interest, establishment]
# 19  [lodging, point_of_interest, establishment]
# 20  [lodging, point_of_interest, establishment]
# 21  [lodging, point_of_interest, establishment]
# 22  [lodging, point_of_interest, establishment]
# 23  [lodging, point_of_interest, establishment]
# 24  [lodging, point_of_interest, establishment]
# 25  [lodging, point_of_interest, establishment]
# 26  [lodging, point_of_interest, establishment]
# 27  [lodging, point_of_interest, establishment]
# 28  [lodging, point_of_interest, establishment]
# 29  [lodging, point_of_interest, establishment]
# 30  [lodging, point_of_interest, establishment]
# 31  [lodging, point_of_interest, establishment]
# 32  [lodging, point_of_interest, establishment]
# 33  [lodging, point_of_interest, establishment]
# 34  [lodging, point_of_interest, establishment]
# 35  [lodging, point_of_interest, establishment]
# 36  [lodging, point_of_interest, establishment]
# 37  [lodging, point_of_interest, establishment]
# 38  [lodging, point_of_interest, establishment]
# 39  [lodging, point_of_interest, establishment]

# %%
# Build base url for text search 
nearby_type = "lodging"
target_coordinates = '41.5048, -81.6857'
radius = 1609
target_search = 'hotel'

nearby_url3 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?pagetoken=CtQDxQEAAHP-eofUyUhkQKLM3bteq6fF8YmhTngdVcRPIE-3jWrzytdLN7eRFp8RNFEv2f1m3s--89D1AKJ-jj0-v1S9UYn5YCXX4-wX48wWrVWeKBsFuJVmNWSxZVQrPoi65Qo0PPOR4HQIKcOIGK13KoRwVcETXUb4PcHJzEdH1beZXNkB6sGLVL5EEAgbXGh7Ac8dfDAedlROxwapMvmJuQOFLjYjwlany5YveJHxWjYYw7ANyXM2qJphcK-3G8A1W0jN_HB_nsplCO4tqdQIrbZ4FpUxnU-EKvi6XKbcdW8nxGXfsZPP3vyNdHAZrVTdiMcz5NczmYjxftBum30pfdwHO88e_a_uf5_qY4jrkJTWbzDo05itKmMjnklvAwwj6t2qKOV_c-d5Lg_y1BnAXDLjy-56NBBw41K2NWbpVEtm8YhQnNKpZBks63cdHwYg_eBukZjaSacEtep4zPEnsyRl7cteh0xwuzqSqtHUk6fCV36hN_yKCL32RrMu6fWz8G1nMhabbYLUKt_Ci0PtG_KSkpNXkPwP0ytm7EsLY0512x2rapFhAk0di2yNh1ObVj-i9MorP3jLt4g64mP6ix1Li9S6hp-y2nnVLuBB9oCcjv22EhC-TC633ik6rgBUJEhUGwUrGhTinhof5KsY2WJmN_1OUOGK9Nz3eA"

params = {"type" : nearby_type,
          'keyword' : target_search,
         "location" : target_coordinates,
          'radius': radius,
         "key" : gkey}

response = requests.get(nearby_url3, params=params)
cleveland_nearby3 = response.json()

print(json.dumps(cleveland_nearby3, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 41.5059501,
#                     "lng": -81.6172965
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.50729702989273,
#                         "lng": -81.61581612010727
#                     },
#                     "southwest": {
#                         "lat": 41.50459737010728,
#                         "lng": -81.61851577989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "c8d0c7cc9d7914d642c6f0527b5cf053c658ea87",
#             "name": "Residence Inn",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107450849509407959993/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAu_2ZBAjoJ1p0-viLGPzoGL7zYlCzBBk15vvBJJKe0enVu7T82jMI80IAb2sYa31q2uvtbEUt7SEqqzlQrGDFvRaJ5QLRf-aYKctkjn8XwDMfFKNuYvrLRp7ibJia9sQsEhBMO6YiYJIYGvP6U-Iza1ULGhTUWFNPX608S9u_yVo-9UDpL-Ymmg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJyU-ZYZD7MIgR0UzjaUGy5tM",
#             "plus_code": {
#                 "compound_code": "G94M+93 Cleveland, Ohio, USA",
#                 "global_code": "86HWG94M+93"
#             },
#             "rating": 3.7,
#             "reference": "ChIJyU-ZYZD7MIgR0UzjaUGy5tM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 6,
#             "vicinity": "1914 E 101st St, Cleveland"
#         }
#     ],
#     "status": "OK"
# }

# %%
#lat3 = []
#lng3 = []
#name3 = []
#place_id3 = []
#rating3 = []
#user_ratings_total3 = []
#types3 = []


# Building lists 
for element in cleveland_nearby3['results']:
    lat.append(element['geometry']['location']['lat'])
    lng.append(element['geometry']['location']['lng'])
    name.append(element['name'])
    place_id.append(element['place_id'])
    rating.append(element['rating'])
    user_ratings_total.append(element['user_ratings_total'])
    types.append(element['types'])

place_df = pd.DataFrame({'Name': name, 'Place_ID': place_id, 'Latitude': lat, 'Longitude': lng, 'Rating': rating,
                          'Total Reviews': user_ratings_total, 'Types': types})
place_df
# Out:
#                                                  Name  \
# 0                         Renaissance Cleveland Hotel
# 1                            Aloft Cleveland Downtown
# 2   DoubleTree by Hilton Hotel Cleveland Downtown ...
# 3                           Hilton Cleveland Downtown
# 4               Hyatt Regency Cleveland At The Arcade
# 5   The Tudor Arms Hotel Cleveland - a DoubleTree ...
# 6              Holiday Inn Express Cleveland Downtown
# 7                Drury Plaza Hotel Cleveland Downtown
# 8         Metropolitan at the 9, Autograph Collection
# 9                Hilton Garden Inn Cleveland Downtown
# 10                      The Westin Cleveland Downtown
# 11                     Hampton Inn Cleveland-Downtown
# 12       Residence Inn by Marriott Cleveland Downtown
# 13  Courtyard by Marriott Cleveland University Circle
# 14                   Radisson Hotel Cleveland-Gateway
# 15                       Holiday Inn Cleveland Clinic
# 16                            Kimpton Schofield Hotel
# 17           Cleveland Marriott Downtown at Key Tower
# 18                         InterContinental Cleveland
# 19            InterContinental Suites Hotel Cleveland
# 20              Hyatt Regency Cleveland At The Arcade
# 21                       Holiday Inn Cleveland Clinic
# 22            InterContinental Suites Hotel Cleveland
# 23                                      Glidden House
# 24                        University Hotel and Suites
# 25                                             Hilton
# 26                                         Park Today
# 27                                 catawba yacht club
# 28                                            redspot
# 29                      1800 Euclid Hospitality Group
# 30         Crowne Plaza Cleveland at Playhouse Square
# 31                A Christmas Story House Loft Rental
# 32                                             hotels
# 33                                 Urban Design Suite
# 34                                        The Alcazar
# 35                                       Casino Hotel
# 36                                                USA
# 37                                   The Bumpus House
# 38                            Hotel Cleveland Gateway
# 39           Travelodge by Wyndham Cleveland Lakewood
# 40                                      Residence Inn
#
#                        Place_ID   Latitude  Longitude  Rating  Total Reviews  \
# 0   ChIJQdJiRX7wMIgRMHYixWs56JQ  41.498611 -81.694472     4.1           1088
# 1   ChIJ-V-1mmLwMIgRCNkQ5iY0w6w  41.500571 -81.704115     4.2           1055
# 2   ChIJkyQK63j6MIgR3WshTHAP94Q  41.507010 -81.690172     4.1           1503
# 3   ChIJ9WAy2YDwMIgRqgktebGbYoM  41.503072 -81.695672     4.5           2141
# 4   ChIJU79i-X_6MIgRgAo4Y1a36zw  41.499789 -81.690841     4.4           1296
# 5   ChIJM5WTlIT7MIgRZXbXABw3OQw  41.500816 -81.612958     4.3            866
# 6   ChIJ8b9IeID6MIgRg7cfACiPh8I  41.500186 -81.688767     4.3            904
# 7   ChIJz9VrMIDwMIgRU4dHrxBVI1k  41.502174 -81.691969     4.6           1050
# 8   ChIJE6DsqoD6MIgRheks77AlZ9w  41.499788 -81.685809     4.5            975
# 9   ChIJtxcBOYb6MIgRW5MU3e2Lqew  41.496152 -81.681146     4.1           1083
# 10  ChIJjQ5B2YHwMIgRjNnpAsJKuBg  41.503725 -81.691413     4.4           1719
# 11  ChIJewgGqX_6MIgRVI5s1kAUzyk  41.502438 -81.689041     4.2            884
# 12  ChIJY8UhA2L6MIgRjU4eiYtqbnM  41.498710 -81.689022     4.4            465
# 13  ChIJ0bg0mIn7MIgRdLO0rIQ4ndc  41.507961 -81.605262     4.3            449
# 14  ChIJA-0v8ID6MIgRBACI0VNvqr8  41.498140 -81.687691     3.9            784
# 15  ChIJx3A1jKL7MIgRQwfzeK-X6Mc  41.503027 -81.626370     4.2            787
# 16  ChIJowjHoID6MIgRYkqUBQC5bmk  41.499811 -81.686762     4.5            532
# 17  ChIJlzqOKX7wMIgRcG1mp3KKt8s  41.501619 -81.693939     4.3           1373
# 18  ChIJm_rT55v7MIgRkVJ4n5CNiOE  41.501449 -81.619343     4.5            685
# 19  ChIJs9bne5j7MIgRK7gn3Ut37mE  41.503065 -81.625300     4.3            423
# 20  ChIJU79i-X_6MIgRgAo4Y1a36zw  41.499789 -81.690841     4.4           1296
# 21  ChIJx3A1jKL7MIgRQwfzeK-X6Mc  41.503027 -81.626370     4.2            787
# 22  ChIJs9bne5j7MIgRK7gn3Ut37mE  41.503065 -81.625300     4.3            423
# 23  ChIJv1Qamov7MIgRAUiBRQkU2-A  41.510944 -81.607877     4.7            337
# 24  ChIJc3VeZFn6MIgRDfZmd6I8NQo  41.502686 -81.661900     2.8            590
# 25  ChIJn72y7Xj6MIgRRjyFgT8IMZk  41.503072 -81.695672     4.8              4
# 26  ChIJp1rJ7n36MIgRwwpkpwISUWw  41.500660 -81.684758     0.0              0
# 27  ChIJF2AFhF76MIgRil1XbzWM2ZM  41.503020 -81.666130     0.0              0
# 28  ChIJDXyNBmb6MIgRvw-P0NGHHXo  41.508507 -81.674464     0.0              0
# 29  ChIJI23g52L6MIgR71RRKXfUJuw  41.500884 -81.678451     4.7              3
# 30  ChIJp252m336MIgRX9QDJIGuKFU  41.500462 -81.683374     4.2            505
# 31  ChIJVeZ366j6MIgRIVvD0qSYsh4  41.468729 -81.687367     5.0              3
# 32  ChIJ3e-GwKj9MIgRXRcfIWWv1to  41.492317 -81.597530     0.0              0
# 33  ChIJa7UAmWj6MIgRySQrPk4BO_E  41.509068 -81.673113     0.0              0
# 34  ChIJ1TzoxJv7MIgRWiijLUrBJrE  41.501603 -81.619175     0.0              0
# 35  ChIJm1xx_rrxMIgRmUQR0Wpz_7o  41.497166 -81.694064     0.0              0
# 36  ChIJq3GuHHjxMIgRVi6vJMesADI  41.499320 -81.694361     0.0              0
# 37  ChIJIRHsk9j7MIgRaAv5LgVWd7Y  41.469037 -81.687374     4.2              5
# 38  ChIJ6xhOyTP7MIgRG5i0LXBcqn8  41.498140 -81.687691     0.0              0
# 39  ChIJ_fHRM4zxMIgRepudzosPQG0  41.490154 -81.770811     3.5            266
# 40  ChIJyU-ZYZD7MIgR0UzjaUGy5tM  41.505950 -81.617296     3.7              6
#
#                                           Types
# 0   [lodging, point_of_interest, establishment]
# 1   [lodging, point_of_interest, establishment]
# 2   [lodging, point_of_interest, establishment]
# 3   [lodging, point_of_interest, establishment]
# 4   [lodging, point_of_interest, establishment]
# 5   [lodging, point_of_interest, establishment]
# 6   [lodging, point_of_interest, establishment]
# 7   [lodging, point_of_interest, establishment]
# 8   [lodging, point_of_interest, establishment]
# 9   [lodging, point_of_interest, establishment]
# 10  [lodging, point_of_interest, establishment]
# 11  [lodging, point_of_interest, establishment]
# 12  [lodging, point_of_interest, establishment]
# 13  [lodging, point_of_interest, establishment]
# 14  [lodging, point_of_interest, establishment]
# 15  [lodging, point_of_interest, establishment]
# 16  [lodging, point_of_interest, establishment]
# 17  [lodging, point_of_interest, establishment]
# 18  [lodging, point_of_interest, establishment]
# 19  [lodging, point_of_interest, establishment]
# 20  [lodging, point_of_interest, establishment]
# 21  [lodging, point_of_interest, establishment]
# 22  [lodging, point_of_interest, establishment]
# 23  [lodging, point_of_interest, establishment]
# 24  [lodging, point_of_interest, establishment]
# 25  [lodging, point_of_interest, establishment]
# 26  [lodging, point_of_interest, establishment]
# 27  [lodging, point_of_interest, establishment]
# 28  [lodging, point_of_interest, establishment]
# 29  [lodging, point_of_interest, establishment]
# 30  [lodging, point_of_interest, establishment]
# 31  [lodging, point_of_interest, establishment]
# 32  [lodging, point_of_interest, establishment]
# 33  [lodging, point_of_interest, establishment]
# 34  [lodging, point_of_interest, establishment]
# 35  [lodging, point_of_interest, establishment]
# 36  [lodging, point_of_interest, establishment]
# 37  [lodging, point_of_interest, establishment]
# 38  [lodging, point_of_interest, establishment]
# 39  [lodging, point_of_interest, establishment]
# 40  [lodging, point_of_interest, establishment]

# %%
place_df.columns
# Out:
# Index(['Name', 'Place_ID', 'Latitude', 'Longitude', 'Rating', 'Total Reviews',
#        'Types'],
#       dtype='object')

# %%
place_df2 = place_df[['Name','Place_ID','Latitude','Longitude','Rating','Total Reviews']]
place_df2
# Out:
#                                                  Name  \
# 0                         Renaissance Cleveland Hotel
# 1                            Aloft Cleveland Downtown
# 2   DoubleTree by Hilton Hotel Cleveland Downtown ...
# 3                           Hilton Cleveland Downtown
# 4               Hyatt Regency Cleveland At The Arcade
# 5   The Tudor Arms Hotel Cleveland - a DoubleTree ...
# 6              Holiday Inn Express Cleveland Downtown
# 7                Drury Plaza Hotel Cleveland Downtown
# 8         Metropolitan at the 9, Autograph Collection
# 9                Hilton Garden Inn Cleveland Downtown
# 10                      The Westin Cleveland Downtown
# 11                     Hampton Inn Cleveland-Downtown
# 12       Residence Inn by Marriott Cleveland Downtown
# 13  Courtyard by Marriott Cleveland University Circle
# 14                   Radisson Hotel Cleveland-Gateway
# 15                       Holiday Inn Cleveland Clinic
# 16                            Kimpton Schofield Hotel
# 17           Cleveland Marriott Downtown at Key Tower
# 18                         InterContinental Cleveland
# 19            InterContinental Suites Hotel Cleveland
# 20              Hyatt Regency Cleveland At The Arcade
# 21                       Holiday Inn Cleveland Clinic
# 22            InterContinental Suites Hotel Cleveland
# 23                                      Glidden House
# 24                        University Hotel and Suites
# 25                                             Hilton
# 26                                         Park Today
# 27                                 catawba yacht club
# 28                                            redspot
# 29                      1800 Euclid Hospitality Group
# 30         Crowne Plaza Cleveland at Playhouse Square
# 31                A Christmas Story House Loft Rental
# 32                                             hotels
# 33                                 Urban Design Suite
# 34                                        The Alcazar
# 35                                       Casino Hotel
# 36                                                USA
# 37                                   The Bumpus House
# 38                            Hotel Cleveland Gateway
# 39           Travelodge by Wyndham Cleveland Lakewood
# 40                                      Residence Inn
#
#                        Place_ID   Latitude  Longitude  Rating  Total Reviews
# 0   ChIJQdJiRX7wMIgRMHYixWs56JQ  41.498611 -81.694472     4.1           1088
# 1   ChIJ-V-1mmLwMIgRCNkQ5iY0w6w  41.500571 -81.704115     4.2           1055
# 2   ChIJkyQK63j6MIgR3WshTHAP94Q  41.507010 -81.690172     4.1           1503
# 3   ChIJ9WAy2YDwMIgRqgktebGbYoM  41.503072 -81.695672     4.5           2141
# 4   ChIJU79i-X_6MIgRgAo4Y1a36zw  41.499789 -81.690841     4.4           1296
# 5   ChIJM5WTlIT7MIgRZXbXABw3OQw  41.500816 -81.612958     4.3            866
# 6   ChIJ8b9IeID6MIgRg7cfACiPh8I  41.500186 -81.688767     4.3            904
# 7   ChIJz9VrMIDwMIgRU4dHrxBVI1k  41.502174 -81.691969     4.6           1050
# 8   ChIJE6DsqoD6MIgRheks77AlZ9w  41.499788 -81.685809     4.5            975
# 9   ChIJtxcBOYb6MIgRW5MU3e2Lqew  41.496152 -81.681146     4.1           1083
# 10  ChIJjQ5B2YHwMIgRjNnpAsJKuBg  41.503725 -81.691413     4.4           1719
# 11  ChIJewgGqX_6MIgRVI5s1kAUzyk  41.502438 -81.689041     4.2            884
# 12  ChIJY8UhA2L6MIgRjU4eiYtqbnM  41.498710 -81.689022     4.4            465
# 13  ChIJ0bg0mIn7MIgRdLO0rIQ4ndc  41.507961 -81.605262     4.3            449
# 14  ChIJA-0v8ID6MIgRBACI0VNvqr8  41.498140 -81.687691     3.9            784
# 15  ChIJx3A1jKL7MIgRQwfzeK-X6Mc  41.503027 -81.626370     4.2            787
# 16  ChIJowjHoID6MIgRYkqUBQC5bmk  41.499811 -81.686762     4.5            532
# 17  ChIJlzqOKX7wMIgRcG1mp3KKt8s  41.501619 -81.693939     4.3           1373
# 18  ChIJm_rT55v7MIgRkVJ4n5CNiOE  41.501449 -81.619343     4.5            685
# 19  ChIJs9bne5j7MIgRK7gn3Ut37mE  41.503065 -81.625300     4.3            423
# 20  ChIJU79i-X_6MIgRgAo4Y1a36zw  41.499789 -81.690841     4.4           1296
# 21  ChIJx3A1jKL7MIgRQwfzeK-X6Mc  41.503027 -81.626370     4.2            787
# 22  ChIJs9bne5j7MIgRK7gn3Ut37mE  41.503065 -81.625300     4.3            423
# 23  ChIJv1Qamov7MIgRAUiBRQkU2-A  41.510944 -81.607877     4.7            337
# 24  ChIJc3VeZFn6MIgRDfZmd6I8NQo  41.502686 -81.661900     2.8            590
# 25  ChIJn72y7Xj6MIgRRjyFgT8IMZk  41.503072 -81.695672     4.8              4
# 26  ChIJp1rJ7n36MIgRwwpkpwISUWw  41.500660 -81.684758     0.0              0
# 27  ChIJF2AFhF76MIgRil1XbzWM2ZM  41.503020 -81.666130     0.0              0
# 28  ChIJDXyNBmb6MIgRvw-P0NGHHXo  41.508507 -81.674464     0.0              0
# 29  ChIJI23g52L6MIgR71RRKXfUJuw  41.500884 -81.678451     4.7              3
# 30  ChIJp252m336MIgRX9QDJIGuKFU  41.500462 -81.683374     4.2            505
# 31  ChIJVeZ366j6MIgRIVvD0qSYsh4  41.468729 -81.687367     5.0              3
# 32  ChIJ3e-GwKj9MIgRXRcfIWWv1to  41.492317 -81.597530     0.0              0
# 33  ChIJa7UAmWj6MIgRySQrPk4BO_E  41.509068 -81.673113     0.0              0
# 34  ChIJ1TzoxJv7MIgRWiijLUrBJrE  41.501603 -81.619175     0.0              0
# 35  ChIJm1xx_rrxMIgRmUQR0Wpz_7o  41.497166 -81.694064     0.0              0
# 36  ChIJq3GuHHjxMIgRVi6vJMesADI  41.499320 -81.694361     0.0              0
# 37  ChIJIRHsk9j7MIgRaAv5LgVWd7Y  41.469037 -81.687374     4.2              5
# 38  ChIJ6xhOyTP7MIgRG5i0LXBcqn8  41.498140 -81.687691     0.0              0
# 39  ChIJ_fHRM4zxMIgRepudzosPQG0  41.490154 -81.770811     3.5            266
# 40  ChIJyU-ZYZD7MIgR0UzjaUGy5tM  41.505950 -81.617296     3.7              6

# %%
# Dropping non-hotels (for example, redspot is a parking garage)
place_df2["Name"] = place_df2["Name"].replace(
    {'The Bumpus House' : 'NaN', 'FLEX Spas Cleveland' : 'NaN',
    'The Alcazar' : 'NaN', 'Park Today' : 'NaN', 'catawba yacht club': 'NaN',
    'redspot' : "NaN", "1800 Euclid Hospitality Group" : "NaN", 
     "A Christmas Story House Loft Rental" : "NaN", 
    'hotels' : 'NaN', 'Urban Design Suite' : 'NaN', 
    "Casino Hotel" : "NaN", "USA" : "NaN"})
place_df2

place_df3 = place_df2.drop_duplicates()
place_df4 = place_df3[place_df3["Name"]!="NaN"]
place_df4


#place_df.drop(place_df.index[26, 27, 28, 29, 31, 32, 33, 34, 35, 36, 37], inplace=True)
#place_df

#place_df.drop(place_df.index[[26, 27, 28, 29, 31, 32, 33, 34, 35, 36, 37]])
# Out:
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                  Name  \
# 0                         Renaissance Cleveland Hotel
# 1                            Aloft Cleveland Downtown
# 2   DoubleTree by Hilton Hotel Cleveland Downtown ...
# 3                           Hilton Cleveland Downtown
# 4               Hyatt Regency Cleveland At The Arcade
# 5   The Tudor Arms Hotel Cleveland - a DoubleTree ...
# 6              Holiday Inn Express Cleveland Downtown
# 7                Drury Plaza Hotel Cleveland Downtown
# 8         Metropolitan at the 9, Autograph Collection
# 9                Hilton Garden Inn Cleveland Downtown
# 10                      The Westin Cleveland Downtown
# 11                     Hampton Inn Cleveland-Downtown
# 12       Residence Inn by Marriott Cleveland Downtown
# 13  Courtyard by Marriott Cleveland University Circle
# 14                   Radisson Hotel Cleveland-Gateway
# 15                       Holiday Inn Cleveland Clinic
# 16                            Kimpton Schofield Hotel
# 17           Cleveland Marriott Downtown at Key Tower
# 18                         InterContinental Cleveland
# 19            InterContinental Suites Hotel Cleveland
# 23                                      Glidden House
# 24                        University Hotel and Suites
# 25                                             Hilton
# 30         Crowne Plaza Cleveland at Playhouse Square
# 38                            Hotel Cleveland Gateway
# 39           Travelodge by Wyndham Cleveland Lakewood
# 40                                      Residence Inn
#
#                        Place_ID   Latitude  Longitude  Rating  Total Reviews
# 0   ChIJQdJiRX7wMIgRMHYixWs56JQ  41.498611 -81.694472     4.1           1088
# 1   ChIJ-V-1mmLwMIgRCNkQ5iY0w6w  41.500571 -81.704115     4.2           1055
# 2   ChIJkyQK63j6MIgR3WshTHAP94Q  41.507010 -81.690172     4.1           1503
# 3   ChIJ9WAy2YDwMIgRqgktebGbYoM  41.503072 -81.695672     4.5           2141
# 4   ChIJU79i-X_6MIgRgAo4Y1a36zw  41.499789 -81.690841     4.4           1296
# 5   ChIJM5WTlIT7MIgRZXbXABw3OQw  41.500816 -81.612958     4.3            866
# 6   ChIJ8b9IeID6MIgRg7cfACiPh8I  41.500186 -81.688767     4.3            904
# 7   ChIJz9VrMIDwMIgRU4dHrxBVI1k  41.502174 -81.691969     4.6           1050
# 8   ChIJE6DsqoD6MIgRheks77AlZ9w  41.499788 -81.685809     4.5            975
# 9   ChIJtxcBOYb6MIgRW5MU3e2Lqew  41.496152 -81.681146     4.1           1083
# 10  ChIJjQ5B2YHwMIgRjNnpAsJKuBg  41.503725 -81.691413     4.4           1719
# 11  ChIJewgGqX_6MIgRVI5s1kAUzyk  41.502438 -81.689041     4.2            884
# 12  ChIJY8UhA2L6MIgRjU4eiYtqbnM  41.498710 -81.689022     4.4            465
# 13  ChIJ0bg0mIn7MIgRdLO0rIQ4ndc  41.507961 -81.605262     4.3            449
# 14  ChIJA-0v8ID6MIgRBACI0VNvqr8  41.498140 -81.687691     3.9            784
# 15  ChIJx3A1jKL7MIgRQwfzeK-X6Mc  41.503027 -81.626370     4.2            787
# 16  ChIJowjHoID6MIgRYkqUBQC5bmk  41.499811 -81.686762     4.5            532
# 17  ChIJlzqOKX7wMIgRcG1mp3KKt8s  41.501619 -81.693939     4.3           1373
# 18  ChIJm_rT55v7MIgRkVJ4n5CNiOE  41.501449 -81.619343     4.5            685
# 19  ChIJs9bne5j7MIgRK7gn3Ut37mE  41.503065 -81.625300     4.3            423
# 23  ChIJv1Qamov7MIgRAUiBRQkU2-A  41.510944 -81.607877     4.7            337
# 24  ChIJc3VeZFn6MIgRDfZmd6I8NQo  41.502686 -81.661900     2.8            590
# 25  ChIJn72y7Xj6MIgRRjyFgT8IMZk  41.503072 -81.695672     4.8              4
# 30  ChIJp252m336MIgRX9QDJIGuKFU  41.500462 -81.683374     4.2            505
# 38  ChIJ6xhOyTP7MIgRG5i0LXBcqn8  41.498140 -81.687691     0.0              0
# 39  ChIJ_fHRM4zxMIgRepudzosPQG0  41.490154 -81.770811     3.5            266
# 40  ChIJyU-ZYZD7MIgR0UzjaUGy5tM  41.505950 -81.617296     3.7              6

# %%
# Reset the index 
place_df5 = place_df4.reset_index()
place_df5

del place_df5['index']
place_df5
# Out:
#                                                  Name  \
# 0                         Renaissance Cleveland Hotel
# 1                            Aloft Cleveland Downtown
# 2   DoubleTree by Hilton Hotel Cleveland Downtown ...
# 3                           Hilton Cleveland Downtown
# 4               Hyatt Regency Cleveland At The Arcade
# 5   The Tudor Arms Hotel Cleveland - a DoubleTree ...
# 6              Holiday Inn Express Cleveland Downtown
# 7                Drury Plaza Hotel Cleveland Downtown
# 8         Metropolitan at the 9, Autograph Collection
# 9                Hilton Garden Inn Cleveland Downtown
# 10                      The Westin Cleveland Downtown
# 11                     Hampton Inn Cleveland-Downtown
# 12       Residence Inn by Marriott Cleveland Downtown
# 13  Courtyard by Marriott Cleveland University Circle
# 14                   Radisson Hotel Cleveland-Gateway
# 15                       Holiday Inn Cleveland Clinic
# 16                            Kimpton Schofield Hotel
# 17           Cleveland Marriott Downtown at Key Tower
# 18                         InterContinental Cleveland
# 19            InterContinental Suites Hotel Cleveland
# 20                                      Glidden House
# 21                        University Hotel and Suites
# 22                                             Hilton
# 23         Crowne Plaza Cleveland at Playhouse Square
# 24                            Hotel Cleveland Gateway
# 25           Travelodge by Wyndham Cleveland Lakewood
# 26                                      Residence Inn
#
#                        Place_ID   Latitude  Longitude  Rating  Total Reviews
# 0   ChIJQdJiRX7wMIgRMHYixWs56JQ  41.498611 -81.694472     4.1           1088
# 1   ChIJ-V-1mmLwMIgRCNkQ5iY0w6w  41.500571 -81.704115     4.2           1055
# 2   ChIJkyQK63j6MIgR3WshTHAP94Q  41.507010 -81.690172     4.1           1503
# 3   ChIJ9WAy2YDwMIgRqgktebGbYoM  41.503072 -81.695672     4.5           2141
# 4   ChIJU79i-X_6MIgRgAo4Y1a36zw  41.499789 -81.690841     4.4           1296
# 5   ChIJM5WTlIT7MIgRZXbXABw3OQw  41.500816 -81.612958     4.3            866
# 6   ChIJ8b9IeID6MIgRg7cfACiPh8I  41.500186 -81.688767     4.3            904
# 7   ChIJz9VrMIDwMIgRU4dHrxBVI1k  41.502174 -81.691969     4.6           1050
# 8   ChIJE6DsqoD6MIgRheks77AlZ9w  41.499788 -81.685809     4.5            975
# 9   ChIJtxcBOYb6MIgRW5MU3e2Lqew  41.496152 -81.681146     4.1           1083
# 10  ChIJjQ5B2YHwMIgRjNnpAsJKuBg  41.503725 -81.691413     4.4           1719
# 11  ChIJewgGqX_6MIgRVI5s1kAUzyk  41.502438 -81.689041     4.2            884
# 12  ChIJY8UhA2L6MIgRjU4eiYtqbnM  41.498710 -81.689022     4.4            465
# 13  ChIJ0bg0mIn7MIgRdLO0rIQ4ndc  41.507961 -81.605262     4.3            449
# 14  ChIJA-0v8ID6MIgRBACI0VNvqr8  41.498140 -81.687691     3.9            784
# 15  ChIJx3A1jKL7MIgRQwfzeK-X6Mc  41.503027 -81.626370     4.2            787
# 16  ChIJowjHoID6MIgRYkqUBQC5bmk  41.499811 -81.686762     4.5            532
# 17  ChIJlzqOKX7wMIgRcG1mp3KKt8s  41.501619 -81.693939     4.3           1373
# 18  ChIJm_rT55v7MIgRkVJ4n5CNiOE  41.501449 -81.619343     4.5            685
# 19  ChIJs9bne5j7MIgRK7gn3Ut37mE  41.503065 -81.625300     4.3            423
# 20  ChIJv1Qamov7MIgRAUiBRQkU2-A  41.510944 -81.607877     4.7            337
# 21  ChIJc3VeZFn6MIgRDfZmd6I8NQo  41.502686 -81.661900     2.8            590
# 22  ChIJn72y7Xj6MIgRRjyFgT8IMZk  41.503072 -81.695672     4.8              4
# 23  ChIJp252m336MIgRX9QDJIGuKFU  41.500462 -81.683374     4.2            505
# 24  ChIJ6xhOyTP7MIgRG5i0LXBcqn8  41.498140 -81.687691     0.0              0
# 25  ChIJ_fHRM4zxMIgRepudzosPQG0  41.490154 -81.770811     3.5            266
# 26  ChIJyU-ZYZD7MIgR0UzjaUGy5tM  41.505950 -81.617296     3.7              6
